# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("yasirabdaali/arxivorg-ai-research-papers-dataset")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("yasirabdaali/arxivorg-ai-research-papers-dataset")
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
# %pip install marker-pdf

from marker.converters.pdf import PdfConverter
from marker.models import create_model_dict
from marker.output import text_from_rendered

converter = PdfConverter(
    artifact_dict=create_model_dict(),
)
rendered = converter("FILEPATH")
text, _, images = text_from_rendered(rendered)
# Out:
# Collecting marker-pdf
#   Using cached marker_pdf-1.6.1-py3-none-any.whl.metadata (27 kB)
# Collecting Pillow<11.0.0,>=10.1.0 (from marker-pdf)
#   Downloading pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting anthropic<0.47.0,>=0.46.0 (from marker-pdf)
#   Using cached anthropic-0.46.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from marker-pdf) (8.1.8)
# Collecting filetype<2.0.0,>=1.2.0 (from marker-pdf)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting ftfy<7.0.0,>=6.1.1 (from marker-pdf)
#   Using cached ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting google-genai<2.0.0,>=1.0.0 (from marker-pdf)
#   Using cached google_genai-1.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting markdown2<3.0.0,>=2.5.2 (from marker-pdf)
#   Using cached markdown2-2.5.3-py3-none-any.whl.metadata (2.1 kB)
# Collecting markdownify<0.14.0,>=0.13.1 (from marker-pdf)
#   Using cached markdownify-0.13.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting pdftext<0.7.0,>=0.6.2 (from marker-pdf)
#   Using cached pdftext-0.6.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from marker-pdf) (2.10.6)
# Collecting pydantic-settings<3.0.0,>=2.0.3 (from marker-pdf)
#   Using cached pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from marker-pdf)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting rapidfuzz<4.0.0,>=3.8.1 (from marker-pdf)
#   Downloading rapidfuzz-3.12.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Requirement already satisfied: regex<2025.0.0,>=2024.4.28 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from marker-pdf) (2024.11.6)
# Collecting scikit-learn<2.0.0,>=1.6.1 (from marker-pdf)
#   Downloading scikit_learn-1.6.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting surya-ocr<0.14.0,>=0.13.0 (from marker-pdf)
#   Using cached surya_ocr-0.13.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: torch<3.0.0,>=2.5.1 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from marker-pdf) (2.5.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from marker-pdf) (4.67.1)
# Requirement already satisfied: transformers<5.0.0,>=4.45.2 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from marker-pdf) (4.47.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from anthropic<0.47.0,>=0.46.0->marker-pdf) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from anthropic<0.47.0,>=0.46.0->marker-pdf) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from anthropic<0.47.0,>=0.46.0->marker-pdf) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from anthropic<0.47.0,>=0.46.0->marker-pdf) (0.8.2)
# Requirement already satisfied: sniffio in /Users/lsc/miniforge3/lib/python3.12/site-packages (from anthropic<0.47.0,>=0.46.0->marker-pdf) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from anthropic<0.47.0,>=0.46.0->marker-pdf) (4.12.2)
# Requirement already satisfied: wcwidth in /Users/lsc/miniforge3/lib/python3.12/site-packages (from ftfy<7.0.0,>=6.1.1->marker-pdf) (0.2.13)
# Collecting google-auth<3.0.0dev,>=2.14.1 (from google-genai<2.0.0,>=1.0.0->marker-pdf)
#   Using cached google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting requests<3.0.0dev,>=2.28.1 (from google-genai<2.0.0,>=1.0.0->marker-pdf)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting websockets<15.0dev,>=13.0 (from google-genai<2.0.0,>=1.0.0->marker-pdf)
#   Downloading websockets-14.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting beautifulsoup4<5,>=4.9 (from markdownify<0.14.0,>=0.13.1->marker-pdf)
#   Using cached beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: six<2,>=1.15 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from markdownify<0.14.0,>=0.13.1->marker-pdf) (1.17.0)
# Collecting pypdfium2==4.30.0 (from pdftext<0.7.0,>=0.6.2->marker-pdf)
#   Using cached pypdfium2-4.30.0-py3-none-macosx_11_0_arm64.whl.metadata (48 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.2->marker-pdf) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.2->marker-pdf) (2.27.2)
# Requirement already satisfied: numpy>=1.19.5 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from scikit-learn<2.0.0,>=1.6.1->marker-pdf) (2.2.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from scikit-learn<2.0.0,>=1.6.1->marker-pdf) (1.15.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from scikit-learn<2.0.0,>=1.6.1->marker-pdf) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from scikit-learn<2.0.0,>=1.6.1->marker-pdf) (3.5.0)
# Collecting opencv-python-headless<5.0.0.0,>=4.11.0.86 (from surya-ocr<0.14.0,>=0.13.0->marker-pdf)
#   Using cached opencv_python_headless-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: platformdirs<5.0.0,>=4.3.6 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from surya-ocr<0.14.0,>=0.13.0->marker-pdf) (4.3.6)
# Requirement already satisfied: filelock in /Users/lsc/miniforge3/lib/python3.12/site-packages (from torch<3.0.0,>=2.5.1->marker-pdf) (3.17.0)
# Requirement already satisfied: networkx in /Users/lsc/miniforge3/lib/python3.12/site-packages (from torch<3.0.0,>=2.5.1->marker-pdf) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from torch<3.0.0,>=2.5.1->marker-pdf) (3.0.0)
# Requirement already satisfied: fsspec in /Users/lsc/miniforge3/lib/python3.12/site-packages (from torch<3.0.0,>=2.5.1->marker-pdf) (2024.12.0)
# Requirement already satisfied: setuptools in /Users/lsc/miniforge3/lib/python3.12/site-packages (from torch<3.0.0,>=2.5.1->marker-pdf) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from torch<3.0.0,>=2.5.1->marker-pdf) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from sympy==1.13.1->torch<3.0.0,>=2.5.1->marker-pdf) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.45.2->marker-pdf) (0.27.1)
# Requirement already satisfied: packaging>=20.0 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.45.2->marker-pdf) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.45.2->marker-pdf) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.45.2->marker-pdf) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.45.2->marker-pdf) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->anthropic<0.47.0,>=0.46.0->marker-pdf) (2.10)
# Collecting soupsieve>1.2 (from beautifulsoup4<5,>=4.9->markdownify<0.14.0,>=0.13.1->marker-pdf)
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.0dev,>=2.14.1->google-genai<2.0.0,>=1.0.0->marker-pdf)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0dev,>=2.14.1->google-genai<2.0.0,>=1.0.0->marker-pdf)
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0dev,>=2.14.1->google-genai<2.0.0,>=1.0.0->marker-pdf)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: certifi in /Users/lsc/miniforge3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->anthropic<0.47.0,>=0.46.0->marker-pdf) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/lsc/miniforge3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->anthropic<0.47.0,>=0.46.0->marker-pdf) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic<0.47.0,>=0.46.0->marker-pdf) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from requests<3.0.0dev,>=2.28.1->google-genai<2.0.0,>=1.0.0->marker-pdf) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from requests<3.0.0dev,>=2.28.1->google-genai<2.0.0,>=1.0.0->marker-pdf) (1.26.20)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in /Users/lsc/miniforge3/lib/python3.12/site-packages (from jinja2->torch<3.0.0,>=2.5.1->marker-pdf) (3.0.2)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-genai<2.0.0,>=1.0.0->marker-pdf)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Using cached marker_pdf-1.6.1-py3-none-any.whl (162 kB)
# Using cached anthropic-0.46.0-py3-none-any.whl (223 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached ftfy-6.3.1-py3-none-any.whl (44 kB)
# Using cached google_genai-1.5.0-py3-none-any.whl (142 kB)
# Using cached markdown2-2.5.3-py3-none-any.whl (48 kB)
# Using cached markdownify-0.13.1-py3-none-any.whl (10 kB)
# Using cached pdftext-0.6.2-py3-none-any.whl (23 kB)
# Using cached pypdfium2-4.30.0-py3-none-macosx_11_0_arm64.whl (2.7 MB)
# Downloading pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 9.3 MB/s eta 0:00:00ta 0:00:01
# Using cached pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading rapidfuzz-3.12.2-cp312-cp312-macosx_11_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.6 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.1-cp312-cp312-macosx_12_0_arm64.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 7.8 MB/s eta 0:00:00 0:00:01m
# Using cached surya_ocr-0.13.0-py3-none-any.whl (154 kB)
# Using cached beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
# Using cached google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Using cached opencv_python_headless-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (37.3 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading websockets-14.2-cp312-cp312-macosx_11_0_arm64.whl (160 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: filetype, websockets, soupsieve, requests, rapidfuzz, python-dotenv, pypdfium2, pyasn1, Pillow, opencv-python-headless, markdown2, ftfy, cachetools, scikit-learn, rsa, pyasn1-modules, beautifulsoup4, pydantic-settings, markdownify, google-auth, anthropic, pdftext, google-genai, surya-ocr, marker-pdf
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.0
#     Uninstalling scikit-learn-1.6.0:
#       Successfully uninstalled scikit-learn-1.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# marker 2.1.5 requires requests==2.25.1, but you have requests 2.32.3 which is incompatible.
# datasets 3.2.0 requires fsspec[http]<=2024.9.0,>=2023.1.0, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed Pillow-10.4.0 anthropic-0.46.0 beautifulsoup4-4.13.3 cachetools-5.5.2 filetype-1.2.0 ftfy-6.3.1 google-auth-2.38.0 google-genai-1.5.0 markdown2-2.5.3 markdownify-0.13.1 marker-pdf-1.6.1 opencv-python-headless-4.11.0.86 pdftext-0.6.2 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydantic-settings-2.8.1 pypdfium2-4.30.0 python-dotenv-1.0.1 rapidfuzz-3.12.2 requests-2.32.3 rsa-4.9 scikit-learn-1.6.1 soupsieve-2.6 surya-ocr-0.13.0 websockets-14.2
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 get_ipython().run_line_magic('pip', 'install marker-pdf')
# ----> 3 from marker.converters.pdf import PdfConverter
#       4 from marker.models import create_model_dict
#       5 from marker.output import text_from_rendered
#
# File ~/miniforge3/lib/python3.12/site-packages/marker/converters/__init__.py:6
#       2 from typing import Optional, List, Type
#       4 from pydantic import BaseModel
# ----> 6 from marker.processors import BaseProcessor
#       7 from marker.processors.llm import BaseLLMSimpleBlockProcessor
#       8 from marker.processors.llm.llm_meta import LLMSimpleBlockMetaProcessor
#
# File ~/miniforge3/lib/python3.12/site-packages/marker/processors/__init__.py:6
#       3 from pydantic import BaseModel
#       5 from marker.schema import BlockTypes
# ----> 6 from marker.schema.document import Document
#       7 from marker.util import assign_config
#      10 class BaseProcessor:
#
# File ~/miniforge3/lib/python3.12/site-packages/marker/schema/document.py:9
#       7 from marker.schema import BlockTypes
#       8 from marker.schema.blocks import Block, BlockId, BlockOutput
# ----> 9 from marker.schema.groups.page import PageGroup
#      12 class DocumentOutput(BaseModel):
#      13     children: List[BlockOutput]
#
# File ~/miniforge3/lib/python3.12/site-packages/marker/schema/groups/__init__.py:6
#       4 from marker.schema.groups.list import ListGroup
#       5 from marker.schema.groups.picture import PictureGroup
# ----> 6 from marker.schema.groups.page import PageGroup
#
# File ~/miniforge3/lib/python3.12/site-packages/marker/schema/groups/page.py:9
#       6 from pdftext.schema import Reference
#       7 from pydantic import computed_field
# ----> 9 from marker.providers import ProviderOutput
#      10 from marker.schema import BlockTypes
#      11 from marker.schema.blocks import Block, BlockId, Text
#
# File ~/miniforge3/lib/python3.12/site-packages/marker/providers/__init__.py:13
#      11 from marker.schema.text import Span
#      12 from marker.schema.text.line import Line
# ---> 13 from marker.settings import settings
#      14 from marker.util import assign_config
#      16 configure_logging()
#
# ImportError: cannot import name 'settings' from 'marker.settings' (/Users/lsc/miniforge3/lib/python3.12/site-packages/marker/settings.py)
