# %%
from kokoro import KPipeline
from IPython.display import display, Audio
import soundfile as sf
import os
import shutil

# 'a' = American English, 🇬'b' => British English
pipeline = KPipeline(lang_code='a', repo_id='hexgrad/Kokoro-82M') # <= make sure lang_code matches voice
# Out:
# /Users/lsc/miniforge3/lib/python3.12/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn(
# /Users/lsc/miniforge3/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %%
VOICE = 'af_heart'

# %%
text = ""
article_name = "attentionisallyouneed"

with open(f'conversions/{article_name}.md') as f:
    text += f.read()

# %%
cut_text = text[:500]
print(cut_text)
# Out:
# Provided proper attribution is provided, Google hereby grants permission to reproduce the tables and figures in this paper solely for use in journalistic or scholarly works.
#
# # Attention Is All You Need
#
# Ashish Vaswani<sup>∗</sup> Google Brain avaswani@google.com
#
# Llion Jones<sup>∗</sup> Google Research llion@google.com
#
# Noam Shazeer<sup>∗</sup> Google Brain noam@google.com
#
# Aidan N. Gomez∗ † University of Toronto aidan@cs.toronto.edu
#
# Niki Parmar<sup>∗</sup> Google Research nikip@google.com
#
# Ja

# %%
generator = pipeline(
    cut_text, 
    voice=VOICE,
    speed=1, 
    split_pattern=r'\n+'
)

# %%
output_dir = "sound_files"

if os.path.exists(output_dir):
    shutil.rmtree(output_dir)

os.makedirs(output_dir)

for i, (gs, ps, audio) in enumerate(generator):
    print(i)  
    print(gs) 
    print(ps) 
    display(Audio(data=audio, rate=24000, autoplay=i==0))

    output_path = os.path.join(output_dir, f"{i}.wav")
    sf.write(output_path, audio, 24000)
# Out:
# 0
# Provided proper attribution is provided, Google hereby grants permission to reproduce the tables and figures in this paper solely for use in journalistic or scholarly works.
# pɹəvˈIdᵻd pɹˈɑpəɹ ˌætɹəbjˈuʃən ɪz pɹəvˈIdᵻd, ɡˈuɡᵊl hˈɪɹbˌI ɡɹˈænts pəɹmˈɪʃən tə ɹˌipɹədˈus ðə tˈAbᵊlz ænd fˈɪɡjəɹz ɪn ðɪs pˈApəɹ sˈOlli fɔɹ jˈus ɪn ʤˌɜɹnᵊlˈɪstɪk ɔɹ skˈɑləɹli wˈɜɹks.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 1
# # Attention Is All You Need
# hˈæʃ ətˈɛnʧən ˌɪz ˈɔl jˌu nˈid
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 2
# Ashish Vaswani<sup>∗</sup> Google Brain avaswani@google.com
# ...
